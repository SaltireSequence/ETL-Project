# %%
import os
import csv
import pandas as pd

# %%
restaurant_df = pd.read_csv('raw.csv')

# %%
restaurant_df.head()
# Out:
#                 restaurant           address           city            state  \
# 0   Chipotle Mexican Grill           126 New  San Francisco   'region': 'CA'
# 1          In-N-Out Burger  333 Jefferson St  San Francisco   'region': 'CA'
# 2    Pearls Deluxe Burgers       708 Post St  San Francisco   'region': 'CA'
# 3           Cafe Du Soleil   200 Fillmore St  San Francisco   'region': 'CA'
# 4                Cafe Zazo        64 14th St  San Francisco   'region': 'CA'
#
#   country                latitude                  longitude  \
# 0      US   'latitude': 37.787086   'longitude': -122.400212
# 1      US     'latitude': 37.8078   'longitude': -122.418383
# 2      US   'latitude': 37.787739   'longitude': -122.413641
# 3      US   'latitude': 37.771303   'longitude': -122.430158
# 4      US   'latitude': 37.768642   'longitude': -122.414821
#
#                         tel    website          price          rating
# ...

# %%
restaurant_dfdata['result'] = data['result'].map(lambda x: x.lstrip('+-').rstrip('aAbBcC'))
